# %% [markdown]
# ## Clone the Repo

# %%
from kaggle_secrets import UserSecretsClient
import os

# Load secret (Personal Access Token) securely
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("frmdl_bdq")

# GitHub repo details
user = "cactusutcac"
repo = "frmdl25-6"
branch = "main"

# Clone the specific branch
# !git clone --branch {branch} https://{token}:x-oauth-basic@github.com/{user}/{repo}.git
# Out:
# Cloning into 'frmdl25-6'...
# remote: Enumerating objects: 4633, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 4633 (delta 73), reused 73 (delta 60), pack-reused 4529 (from 2)
# Receiving objects: 100% (4633/4633), 1.36 GiB | 21.75 MiB/s, done.
# Resolving deltas: 100% (250/250), done.
# Updating files: 100% (1721/1721), done.

# %% [markdown]
# ## Install Dependecies

# %%
# !pip install numpy torch matplotlib git+https://github.com/facebookresearch/pytorchvideo.git torchvision lightning opencv-python tensorflow
# Out:
# Collecting git+https://github.com/facebookresearch/pytorchvideo.git
#   Cloning https://github.com/facebookresearch/pytorchvideo.git to /tmp/pip-req-build-xsb4qe9p
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorchvideo.git /tmp/pip-req-build-xsb4qe9p
#   Resolved https://github.com/facebookresearch/pytorchvideo.git to commit 6cdc929315aab1b5674b6dcf73b16ec99147735f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Collecting lightning
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Collecting fvcore (from pytorchvideo==0.1.5)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo==0.1.5)
#   Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting parameterized (from pytorchvideo==0.1.5)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo==0.1.5)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (0.14.3)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (1.7.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning) (2.5.1.post0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.18)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo==0.1.5)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fvcore->pytorchvideo==0.1.5) (0.9.0)
# Collecting portalocker (from iopath->pytorchvideo==0.1.5)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.20.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.7 MB/s eta 0:00:00:00:0100:01
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 44.7 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.4 MB/s eta 0:00:00
# Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 50.6 MB/s eta 0:00:00:00:0100:01
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=213014 sha256=8aed6cc1e4bb54bb17b22fabe9ba48ff13ae387b0876ae7cfec75939fd909615
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w48juudk/wheels/e3/00/83/9078ad0db7245b3cb777e4afbc737c8a584a8fc347f4438962
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=9998808eff22f324f03d684118f038c99e78b67256acd96a161094c51fccd14f
#   Stored in directory: /root/.cache/pip/wheels/65/71/95/3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=abe4277f29edb9310f8cd26e84ddc08af3ad570783e201bb767331a0fa682759
#   Stored in directory: /root/.cache/pip/wheels/ba/5e/16/6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, portalocker, parameterized, packaging, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, av, nvidia-cusparse-cu12, nvidia-cudnn-cu12, iopath, nvidia-cusolver-cu12, fvcore, pytorchvideo, lightning
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed av-14.4.0 fvcore-0.1.5.post20221221 iopath-0.1.10 lightning-2.5.1.post0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 packaging-24.2 parameterized-0.9.0 portalocker-3.1.1 pytorchvideo-0.1.5 yacs-0.1.8

# %% [markdown]
# ## Training

# %%
# %load_ext tensorboard

# %%
# !touch /kaggle/working/frmdl25-6/datasets/__init__.py

# %%
# %cd /kaggle/working/frmdl25-6/
from training import main
main('ixmas')
# Out:
# /kaggle/working/frmdl25-6
# IXMAS_LABELS_DIR used: ./datasets/ixmas_clips_6.json
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
#
# Validating epoch...:   0%|          | 0/8 [00:00<?, ?batch/s]
# Validating epoch...:  12%|█▎        | 1/8 [00:01<00:11,  1.58s/batch]
# Validating epoch...:  25%|██▌       | 2/8 [00:02<00:06,  1.09s/batch]
# Validating epoch...:  38%|███▊      | 3/8 [00:03<00:04,  1.07batch/s]
# Validating epoch...:  50%|█████     | 4/8 [00:03<00:03,  1.16batch/s]
# Validating epoch...:  62%|██████▎   | 5/8 [00:04<00:02,  1.21batch/s]
# Validating epoch...:  75%|███████▌  | 6/8 [00:05<00:01,  1.25batch/s]
# Validating epoch...:  88%|████████▊ | 7/8 [00:06<00:00,  1.28batch/s]
# Validating epoch...: 100%|██████████| 8/8 [00:06<00:00,  1.43batch/s]
# Action accuracy: 0.5333, Privacy accuracy: 0.1101
# Action Loss: 11.6468, Privacy Loss: 19.5981
# Adversarial training: 100%|██████████| 50/50 [00:00<?, ?epoch/s]
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# action ResNet training: 100%|██████████| 50/50 [00:00<?, ?epoch/s]
# privacy ResNet training: 100%|██████████| 50/50 [00:00<?, ?epoch/s]

# %%
# %tensorboard --logdir /kaggle/working/frmdl25-6/checkpoints/runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 4983), started 1:39:12 ago. (Use '!kill 4983' to kill it.)

# %%
# !zip -r /kaggle/working/tensorboard_logs_ixmas.zip /kaggle/working/frmdl25-6/checkpoints/runs/
# Out:
# updating: kaggle/working/frmdl25-6/checkpoints/runs/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_val_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_val_acc_action/events.out.tfevents.1749642494.c819421c4e9f.35.7 (deflated 62%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_val_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_val_acc_action/events.out.tfevents.1749644508.c819421c4e9f.35.23 (deflated 67%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_train_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_train_acc_privacy/events.out.tfevents.1749642494.c819421c4e9f.35.6 (deflated 61%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_train_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_train_loss_action/events.out.tfevents.1749643672.c819421c4e9f.35.9 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_train_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_train_acc_action/events.out.tfevents.1749644508.c819421c4e9f.35.21 (deflated 67%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_val_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_val_loss_action/events.out.tfevents.1749643672.c819421c4e9f.35.11 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_train_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_train_acc_privacy/events.out.tfevents.1749644508.c819421c4e9f.35.22 (deflated 66%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_train_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_train_loss_action/events.out.tfevents.1749642494.c819421c4e9f.35.1 (deflated 54%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_val_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_val_loss_privacy/events.out.tfevents.1749643672.c819421c4e9f.35.12 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_train_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_train_loss_privacy/events.out.tfevents.1749642494.c819421c4e9f.35.2 (deflated 54%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_train_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_train_acc_action/events.out.tfevents.1749643672.c819421c4e9f.35.13 (deflated 65%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_train_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_action_train_loss_privacy/events.out.tfevents.1749643672.c819421c4e9f.35.10 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_val_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_val_loss_action/events.out.tfevents.1749642494.c819421c4e9f.35.3 (deflated 54%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_val_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_val_loss_privacy/events.out.tfevents.1749644508.c819421c4e9f.35.20 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/events.out.tfevents.1749642462.c819421c4e9f.35.0 (deflated 9%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_val_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_privacy_val_acc_privacy/events.out.tfevents.1749644508.c819421c4e9f.35.24 (deflated 66%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_val_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_val_acc_action/events.out.tfevents.1749643672.c819421c4e9f.35.15 (deflated 67%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_train_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_train_loss_action/events.out.tfevents.1749644508.c819421c4e9f.35.17 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_train_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_train_acc_privacy/events.out.tfevents.1749643672.c819421c4e9f.35.14 (deflated 69%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_train_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_train_loss_privacy/events.out.tfevents.1749644508.c819421c4e9f.35.18 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_val_loss_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_privacy_val_loss_action/events.out.tfevents.1749644508.c819421c4e9f.35.19 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_train_acc_action/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_train_acc_action/events.out.tfevents.1749642494.c819421c4e9f.35.5 (deflated 60%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_val_loss_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Loss_val_loss_privacy/events.out.tfevents.1749642494.c819421c4e9f.35.4 (deflated 53%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_val_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_action_val_acc_privacy/events.out.tfevents.1749643672.c819421c4e9f.35.16 (deflated 69%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_val_acc_privacy/ (stored 0%)
# updating: kaggle/working/frmdl25-6/checkpoints/runs/Accuracy_val_acc_privacy/events.out.tfevents.1749642494.c819421c4e9f.35.8 (deflated 64%)
#   adding: kaggle/working/frmdl25-6/checkpoints/runs/events.out.tfevents.1749651250.c819421c4e9f.35.25 (deflated 9%)
#   adding: kaggle/working/frmdl25-6/checkpoints/runs/events.out.tfevents.1749651277.c819421c4e9f.35.26 (deflated 9%)
